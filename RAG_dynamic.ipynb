# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Arsath Mohamed\AppData\Local\Programs\Python\Python312\python.exe

# %%
from langchain_openai import ChatOpenAI
from langchain_ollama import ChatOllama

llm = ChatOllama(model="llama3")

# %%
llm_local = ChatOpenAI(
    base_url="http://localhost:12434/v1",
    api_key="not-needed",
    model="llama3.1",
    temperature=0.9
)

# %%
from langchain_community.document_loaders import PyMuPDFLoader

loader = PyMuPDFLoader("./VectorStore/enterprise_sales_report.pdf")

docs = loader.load()

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=100
)

chunks = splitter.split_documents(docs)

# %%
from langchain_ollama import OllamaEmbeddings

embedding_model = OllamaEmbeddings(
    model="nomic-embed-text"
)

# %%
from langchain_community.vectorstores import Chroma

vectorstore = Chroma.from_documents(
    
    documents=chunks,
    embedding=embedding_model

)

# %%
print("\n System Ready! Ask your questions (type 'exit' to quit)\n")

while True:
    query = input("Enter your question: ")

    if query.lower() == "exit":
        print(" Exiting...")
        break

    context = vectorstore.similarity_search(query, k=4)

    response = llm.invoke( f"Answer the question based only on the context below:\n\n{context}\n\nQuestion: {query}")

    print("\n Answer:", response.content, "\n")
# Out:
#  System Ready! Ask your questions (type 'exit' to quit)
#
#
#  Answer: Based on the provided context, the regions with non-zero revenue are:
#
# * Pennsylvania (Total Revenue = $441,818.00)
# * Montana (Total Revenue = $2,715.10 + $3,560.88 = $6,276.98)
# * Massachusetts (Total Revenue = $3,560.88)
# * Maryland (Total Revenue = $1,178.58 + $4,117.50 = $5,296.08)
# * Wisconsin (Total Revenue = $300.08)
# * Illinois (Total Revenue = $1,416.66)
# * Hawaii (Total Revenue = $4,117.50)
# * Vermont (Total Revenue = $2,333.82)
# * West Virginia (Total Revenue = $548.87)
# * Delaware (Total Revenue = $3,381.84)
#
# Comparing these values, we can see that Massachusetts has the highest revenue with a total of $3,560.88.
#
#  Exiting...
